# %% [markdown]
# # Kolokvij 1
#
#
#  > Kolokvij se sastoji od  teorijskog i praktičnog dijela. Odgovore na teorijska pitanja upisujete direktno u Jupyter bilježnicu zajedno s programskim kodom. Pored svakog zadatka označeno je broj teorijskih bodova (5) i programerskog (5). Bilježnica s rješenjima se predaje preko Teams-a.
#
# ___

# %% [markdown]
# ## Zadatak 1: (T:5+P:5)

# %% [markdown]
# ### Teorija
#
# Kako se automati konačnog stanja povezuju s regularnim jezicima i zašto su ekvivalentni regularnim izrazima?

# %% [markdown]
# **Odgovor:** ovdje nadopunite vaš odogovor ...

# %% [markdown]
# ### Programiranje:
#
#
# U mapi `data\rjecnik.txt` dano vam je popis riječi sa gramatičkim i semantičkim obilježjima.  Iz teksta izvući samo pridjeve sa opisom i gramatičkim obilježjima i spremiti u JSON datoteku prema sljedećem formatu
#
#
# Npr. tekst:
# ```
# gàelskī
# prid. 〈G gàelskōg(a); ž. gàelskā, s. gàelskō〉 1. koji se odnosi na Škote koji govore keltskim jezikom 2. 〈u im. funkciji〉 〈jd. m.〉 jedan od službenih regionalnih jezika u Škotskoj i narodni jezik Škota koji pripada keltskim jezicima; sin. (škotski)
#
# gajdàšičin
# prid. 〈G gajdàšičina; ž. gajdàšičina, s. gajdàšičino〉 koji pripada gajdašici
#
# ```
#
# treba parsirati u JSON datoteku
#
# ```json
# gàelskī.json
#
#   {
#     "lema": "gàelskī",
#     "pos": "adjective",
#     "inflection": {
#       "genitive": "gàelskōg(a)",
#       "feminine": "gàelskā",
#       "neutral": "gàelskō"
#       },
#     "definition": [
#         "koji se odnosi na Škote koji govore keltskim jezikom",
#         "〈u im. funkciji〉 〈jd. m.〉 jedan od službenih regionalnih jezika u Škotskoj i narodni jezik Škota koji pripada keltskim jezicima; sin. (škotski)"
#         ]
#   }
#
#
# gajdàšičin.json
# [
#   {
#     "lema": "gajdàšičin",
#     "pos": "adjective",
#     "inflection": {
#       "genitive": "gajdàšičina",
#       "feminine": "gajdàšičina",
#       "neutral": "gajdàšičino〉"
#       },
#     "definition": [
#         "koji pripada gajdašici"
#         ]
#   }
#   ]
# ```
#
# Uočite u oba primjera kako moramo definirati genitiv, ženski i srednji rod. Značenje riječi parsiramo u listu (lista ima onoliko elemenata koliko ima značenja riječi)

# %%
# u ovom dijelu nadopišite svoj kod ...

# %% [markdown]
# ___

# %% [markdown]
# ## Zadatak 2 (T:5+P:5)

# %% [markdown]
# ### Teorija:
#
# Kako funkcionira N-gram model, što je Markovljeva pretpostavka i zašto je potrebno zaglađivanje?

# %% [markdown]
# **Odgovor:** ovdje nadopunite vaš odgovor ...

# %% [markdown]
# ### Programiranje:
#
# U ovom zadatku potrebno je izgraditi n-gramski model za roman *C. Dickensa* **Oliver Twist**. Tekst je dan u .txt formatu.
#
# Učinite sljedeće:
#   1. Izgradite skup za treniranje na kojem ćete naučiti model (80% rečenica korpusa). Evaluirajte model uz pomoć mjere perpleksnosti na skupu za testiranje (20%). Na tekstu primijenite neku od normalizacijskih  tehnika (npr. izbacivanje učestalnih riječi iz `data/hr_stopwords.txt`, ...) kako bi dobili što bolju perpleksnost.
#   2. Pored MLE procjenitelja, koristite barem metodu zaglađivanja i interpolacije. Odaberite onu metodu koja daje najbolju perpleksnost.
#   3. Generirajte nekoliko rečenica iz vašeg modela

# %%
# u ovom dijelu nadopišite svoj kod ...

# %% [markdown]
# ___

# %% [markdown]
# # Zadatak 3: (T:5+P:5)

# %% [markdown]
# ### Teorija:
#
# Što je HMM u kontekstu POS označavanja i koja je uloga Viterbi algoritma?

# %% [markdown]
# ### Programiranje:
#
# U ovom zadatku potrebno je implementirati POS označavatelj koristeći n-gramski naivni Bayesov model na primjeru Brown-ovog korpusa žanra `adventure`.
#
# Učinite sljedeće:
#  1. Učitajte korpus i podjelite na skup za treniranje i  testiranje.
#  2. Napravite osnovni POS označavatelj na temelju regularnih izraza
#  3. Napravite unigramski, bigramski i trigramski označavatelj i usporedite rezultate na temelju točnosti
#  4. Povežite POS označvatelje koristeći odstupanje
#  5. Prijavite točnost modela i matricu konfuzije.

# %%
# u ovom dijelu nadopišite svoj kod ...

# %% [markdown]
# ___
